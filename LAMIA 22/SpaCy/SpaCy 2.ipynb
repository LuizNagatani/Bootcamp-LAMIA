# %%
import spacy


# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 11.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('en_core_web_md')

# %%
with open('wiki_us.txt', 'r') as f:
    text = f.read()

# %%
doc = nlp(text)
sentence1 = list(doc.sents)[0]
sentence1
# Out:
# The United States of America (USA), commonly known as the United States (U.S.) or informally America, is a country primarily located in North America.

# %%
import numpy as np

your_word = 'country'

ms = nlp.vocab.vectors.most_similar(
    np.asarray([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]),
    n=10
)

words = [nlp.vocab.strings[w] for w in ms[0][0]]
distances = ms[2]
print(words)
# Out:
# ['country—0,467', 'nationâ\x80\x99s', 'countries-', 'continente', 'Carnations', 'pastille', 'бесплатно', 'Argents', 'Tywysogion', 'Teeters']

# %%
doc1 = nlp('I like salty fries and hamburguers.')
doc2 = nlp('Fast food tastes very good.')

# %%
print(doc1, '<->', doc2, doc1.similarity(doc2)) #analisa a similaridade entre os tokens das duas frases obtendo 67% de similaridade
# pois as duas retratam fast food mesmo não usando as mesmas palavras
# Out:
# I like salty fries and hamburguers. <-> Fast food tastes very good. 0.6786707181458879

# %%
doc3 = nlp('The Empire State Building in is New York.')

# %%
print(doc1, '<->', doc3, doc1.similarity(doc3))
# Out:
# I like salty fries and hamburguers. <-> The Empire State Building in is New York. 0.1840035527750666

# %%
doc4 = nlp('I enjoy oranges.')
doc5 = nlp('I enjoy apples.')

print(doc4, '<->', doc5, doc4.similarity(doc5))
# não retratam a mesma fruta, porém são semelhantes por possuirem a mesma estrutura
# Out:
# I enjoy oranges. <-> I enjoy apples. 0.9775702131220241

# %%
nlp = spacy.blank('en')

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#   'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}}}
