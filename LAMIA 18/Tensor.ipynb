# %%
import torch

# %%
amostra = torch.tensor([2,22])
amostra.shape
#resulta em um tensor 1D com 2 elementos
# Out:
# torch.Size([2])

# %%
x = torch.tensor([[2,22], [4, 20]])
x.shape
#um tensor 2D com 2 elementos em cada dimensão
# Out:
# torch.Size([2, 2])

# %%
x = torch.tensor([[2], [20]])
x.shape
# um tensor 2D com 1 elemento em cada dimensão sendo um tensor com 2 fileiras e uma coluna
# Out:
# torch.Size([2, 1])

# %%
import plotly.graph_objs as go
import plotly.offline as pyo


a = torch.tensor([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

x_val = []
y_val = []
z_val = []
for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        for k in range(a.shape[2]):
            x_val.append(i)
            y_val.append(j)
            z_val.append(k)

trace = go.Scatter3d(
    x=x_val,
    y=y_val,
    z=z_val,
    mode='markers',
    marker=dict(
        size=5,
        color=a.flatten(),
        colorscale='Viridis',
        opacity=0.8
    )
)

layout = go.Layout(
    margin=dict(l=0, r=0, b=0, t=0),
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    )
)

fig = go.Figure(data=[trace], layout=layout)
pyo.plot(fig, filename='tensor.html')
# Out:
# 'tensor.html'
