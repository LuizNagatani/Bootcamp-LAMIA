# %%
import pandas as pd
from IPython.display import clear_output
import keras 
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
X = pd.read_csv('entradas_breast.csv')
y = pd.read_csv('saidas_breast.csv')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
print(X_train.shape, y_train.shape)
# Out:
# (426, 30) (426, 1)

# %%
clas = Sequential()
clas.add(Dense(units=16, activation='relu', 
                        kernel_initializer='random_uniform', input_dim = 30))
clas.add(Dense(units=16, activation='relu', 
                        kernel_initializer='random_uniform'))
clas.add(Dense(units=1, activation='sigmoid'))

# %%
otm = keras.optimizers.Adam(learning_rate=0.001, weight_decay=0.0001, clipvalue=0.5)
clas.compile(optimizer= otm, loss='binary_crossentropy',
                      metrics= ['binary_accuracy'])

# %%
clas.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - binary_accuracy: 0.9617 - loss: 0.0894
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9498 - loss: 0.0751
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9732 - loss: 0.0956
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9777 - loss: 0.1004
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9736 - loss: 0.0549
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9876 - loss: 0.0372
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9752 - loss: 0.0854
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9802 - loss: 0.0571
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.9769 - loss: 0.0654
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9849 - loss: 0.0476
# Epoch 11/100
# ...

# %%
prev=clas.predict(X_test)
prev = (prev > 0.5)
prev
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
# ...

# %%
prec = accuracy_score(y_test, prev)
prec
# Out:
# 0.8671328671328671

# %%
mat = confusion_matrix(y_test, prev)
mat
# Out:
# array([[42, 12],
#        [ 7, 82]], dtype=int64)

# %%
res = clas.evaluate(X_test, y_test)
res
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8845 - loss: 0.5246
# [0.6007639765739441, 0.867132842540741]

# %%
peso0 = clas.layers[0].get_weights()
peso1 = clas.layers[1].get_weights()
peso2 = clas.layers[2].get_weights()
